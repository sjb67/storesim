# %%
import os
import pandas as pd
import random
import altair as alt
from datetime import datetime, timedelta

colors = ["red", "green", "blue", "orange"]
mediums = ["oil", "watercolor", "acrylic", "marker"]

class Analytics:
    def __init__(self):
        self.store_analytics = []

    def add_analytics(self, analytics):
        self.store_analytics = analytics

    def make_csv(self, filename, data):
        df = pd.DataFrame(data)
        print(df)
        df.to_csv(filename, index=False)

class Purchase:
    def __init__(self):
        self.total = 0

    def increment(self, price):
        self.total += price

    def __str__(self):
        return "Sale: $" + str(self.total)

class Inventory:
    def __init__(self):
        self.paints = []

        num_paints = random.randint(10, 20)

        for _ in range(num_paints):
            color = random.choice(colors)
            medium = random.choice(mediums)
            paint = Product(color, medium)
            self.paints.append(paint)

    def add_paint(self, paint):
        self.paints.append(paint)

    def display_order(self):
        for paint in self.paints:
            print(paint)

class Product:
    def __init__(self, color, medium):
        self.price = round(random.uniform(1, 10), 2)
        self.color = color
        self.medium = medium

    def __str__(self):
        return f'Color: {self.color}, Medium: {self.medium}'

class Stand:
    def __init__(self, name):
        self.name = name
        self.inventory = Inventory()
        self.customers = []
        self.purchase = Purchase()

    def add_customer(self, customer):
        self.customers.append(customer)

    def get_customers(self):
        for customer in self.customers:
            print("Customer " + customer.get_name() + " is busy shopping.")

    def run(self):
        print("Welcome to " + self.name + "!")
        self.inventory.display_order()
        print("We have " + str(len(self.customers)) + " customers today.")

        for customer in self.customers:
            print("Customer " + customer.name + " is shopping.")
            item = random.choice(self.inventory.paints)
            customer.add_to_order(item)
            print("Customer " + customer.name + " added " + str(item) + " to their order.")
            self.purchase.increment(item.price)
            print("Customer " + customer.name + " checked out and paid $" + str(item.price) + ".")

        print("The total sales for " + self.name + " today is $" + str(self.purchase.total) + ".")

    def __str__(self):
        return self.name

class Customer:
    def __init__(self, name):
        self.name = name
        self.order = Order()

    def get_name(self):
        return self.name

    def add_to_order(self, product):
        self.order.add(product)

    def __str__(self):
        return self.name + " (" + str(self.order) + ")"

class Order:
    def __init__(self):
        self.products = []

    def add(self, product):
        self.products.append(product)

    def __str__(self):
        result = "Order:\n"
        for product in self.products:
            result += str(product) + "\n"
        return result

stand = Stand("Ken's Paint Shop")

names = ["Jennifer", "Bob", "Charlie", "David", "Eve", "Billie", "Grace", "Aaron", "Ivy", "Lucas"]
for name in names:
    stand.add_customer(Customer(name))

stand.get_customers()
stand.run()

class Organization:
    def __init__(self, name):
        self.name = name
        self.stands = []
        self.analytics = []

    def add_stand(self, stand):
        self.stands.append(stand)

    def simulate(self, start_date, week):
        print("We'd like to welcome you to " + self.name + "!")
        print("We have " + str(len(self.stands)) + " stores in our corporation.")

        for store in self.stands:
            store.run()

        total_sales = sum(store.purchase.total for store in self.stands)
        print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")

        dict_A = {"store_name": self.name, "weekly_sales": total_sales}
        self.analytics.append(dict_A)

        weekly_analytics = Analytics()
        weekly_analytics.add_analytics(self.get_analytics())

        week_start_date = start_date + timedelta(weeks=week)
        filename = week_start_date.strftime('%B-%d-%Y') + '_analytics.csv'
        weekly_analytics.make_csv(filename, self.analytics)
        print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")

    def get_analytics(self):
        return self.analytics

    def display_analytics(self):
        for record in self.analytics:
            print(record)

    def __str__(self):
        result = self.name + ":\n"
        for stand in self.stands:
            result += str(stand) + "\n"
        return result

corp = Organization("Flying Colors")

store1 = Stand("Local Store 1")
store2 = Stand("Local Store 2")
store3 = Stand("Local Store 3")
corp.add_stand(store1)
corp.add_stand(store2)
corp.add_stand(store3)

store1_customers = [Customer(names[i % len(names)]) for i in range(10)]
store2_customers = [Customer(names[i % len(names)]) for i in range(10, 20)]
store3_customers = [Customer(names[i % len(names)]) for i in range(20, 30)]

for customer in store1_customers:
    store1.add_customer(customer)

for customer in store2_customers:
    store2.add_customer(customer)

for customer in store3_customers:
    store3.add_customer(customer)

start_date = datetime(2024, 1, 1)

dataframes = []
for week in range(52):
    print(f"Running simulation for week {week + 1}")
    corp.simulate(start_date, week)
    weekly_analytics = Analytics()
    weekly_analytics.add_analytics(corp.get_analytics())
    week_start_date = start_date + timedelta(weeks=week)
    filename = week_start_date.strftime('%Y-%m-%d') + '_week_' + str(week + 1) + '_analytics.csv'
    weekly_analytics.make_csv(filename, corp.get_analytics())
    dataframes.append(pd.read_csv(filename))
    corp.analytics = []


yearly_data = pd.concat(dataframes, ignore_index=True)

yearly_sales = yearly_data.groupby('store_name')['weekly_sales'].sum().reset_index()

bar_chart = alt.Chart(yearly_sales).mark_bar().encode(
    x='store_name',
    y='weekly_sales',
    color='store_name',
    tooltip=['store_name', 'weekly_sales']
).properties(
    title='Yearly Sales per Store'
)

weekly_sales = yearly_data.groupby(['store_name'])['weekly_sales'].sum().reset_index()

line_chart = alt.Chart(weekly_sales).mark_line().encode(
    x='store_name',
    y='weekly_sales'
)

bar_chart & line_chart
# Out:
# Streaming output truncated to the last 5000 lines.
# Customer Jennifer added Color: orange, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $5.77.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: oil to their order.
# Customer Bob checked out and paid $2.03.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $5.61.
# Customer David is shopping.
# Customer David added Color: blue, Medium: watercolor to their order.
# Customer David checked out and paid $1.42.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: oil to their order.
# Customer Eve checked out and paid $9.6.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: oil to their order.
# Customer Billie checked out and paid $9.78.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: oil to their order.
# Customer Grace checked out and paid $2.03.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: oil to their order.
# Customer Aaron checked out and paid $9.78.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: acrylic to their order.
# Customer Ivy checked out and paid $9.64.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: acrylic to their order.
# Customer Lucas checked out and paid $9.64.
# The total sales for Local Store 1 today is $1279.0499999999981.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: oil to their order.
# Customer Jennifer checked out and paid $7.11.
# Customer Bob is shopping.
# Customer Bob added Color: green, Medium: watercolor to their order.
# Customer Bob checked out and paid $8.74.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: marker to their order.
# Customer Charlie checked out and paid $5.12.
# Customer David is shopping.
# Customer David added Color: red, Medium: watercolor to their order.
# Customer David checked out and paid $5.52.
# Customer Eve is shopping.
# Customer Eve added Color: green, Medium: watercolor to their order.
# Customer Eve checked out and paid $8.74.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: watercolor to their order.
# Customer Billie checked out and paid $5.52.
# Customer Grace is shopping.
# Customer Grace added Color: green, Medium: watercolor to their order.
# Customer Grace checked out and paid $8.74.
# Customer Aaron is shopping.
# Customer Aaron added Color: green, Medium: oil to their order.
# Customer Aaron checked out and paid $8.25.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $1.82.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: watercolor to their order.
# Customer Lucas checked out and paid $1.82.
# The total sales for Local Store 2 today is $1141.8999999999999.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: green, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $5.82.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: marker to their order.
# Customer Bob checked out and paid $4.29.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $6.02.
# Customer David is shopping.
# Customer David added Color: orange, Medium: watercolor to their order.
# Customer David checked out and paid $7.25.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: marker to their order.
# Customer Eve checked out and paid $1.12.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: watercolor to their order.
# Customer Billie checked out and paid $6.02.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: watercolor to their order.
# Customer Grace checked out and paid $7.25.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: acrylic to their order.
# Customer Aaron checked out and paid $8.98.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $4.31.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: acrylic to their order.
# Customer Lucas checked out and paid $4.83.
# The total sales for Local Store 3 today is $1157.3900000000003.
# The total sales for Flying Colors today is $3578.3399999999983.
#       store_name  weekly_sales
# 0  Flying Colors       3578.34
# The total sales for Flying Colors today is $3578.3399999999983.
#       store_name  weekly_sales
# 0  Flying Colors       3578.34
# Running simulation for week 21
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: oil to their order.
# Customer Jennifer checked out and paid $9.6.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: oil to their order.
# Customer Bob checked out and paid $5.4.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: oil to their order.
# Customer Charlie checked out and paid $2.03.
# Customer David is shopping.
# Customer David added Color: orange, Medium: watercolor to their order.
# Customer David checked out and paid $5.77.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: acrylic to their order.
# Customer Eve checked out and paid $9.64.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $8.67.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $8.67.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $9.6.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: oil to their order.
# Customer Ivy checked out and paid $5.4.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: marker to their order.
# Customer Lucas checked out and paid $8.67.
# The total sales for Local Store 1 today is $1352.4999999999984.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: oil to their order.
# Customer Jennifer checked out and paid $7.06.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $1.26.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: oil to their order.
# Customer Charlie checked out and paid $5.51.
# Customer David is shopping.
# Customer David added Color: green, Medium: oil to their order.
# Customer David checked out and paid $8.25.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.5.
# Customer Billie is shopping.
# Customer Billie added Color: green, Medium: oil to their order.
# Customer Billie checked out and paid $8.25.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: watercolor to their order.
# Customer Grace checked out and paid $5.52.
# Customer Aaron is shopping.
# Customer Aaron added Color: green, Medium: marker to their order.
# Customer Aaron checked out and paid $6.74.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $8.65.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: marker to their order.
# Customer Lucas checked out and paid $8.65.
# The total sales for Local Store 2 today is $1207.29.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $8.98.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: marker to their order.
# Customer Bob checked out and paid $4.29.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: acrylic to their order.
# Customer Charlie checked out and paid $8.98.
# Customer David is shopping.
# Customer David added Color: orange, Medium: marker to their order.
# Customer David checked out and paid $4.31.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.0.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: watercolor to their order.
# Customer Billie checked out and paid $5.0.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $8.41.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $4.31.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $4.31.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: watercolor to their order.
# Customer Lucas checked out and paid $9.12.
# The total sales for Local Store 3 today is $1220.1000000000001.
# The total sales for Flying Colors today is $3779.8899999999985.
#       store_name  weekly_sales
# 0  Flying Colors       3779.89
# The total sales for Flying Colors today is $3779.8899999999985.
#       store_name  weekly_sales
# 0  Flying Colors       3779.89
# Running simulation for week 22
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: oil to their order.
# Customer Jennifer checked out and paid $2.03.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $5.61.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: oil to their order.
# Customer Charlie checked out and paid $2.03.
# Customer David is shopping.
# Customer David added Color: blue, Medium: oil to their order.
# Customer David checked out and paid $5.4.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.77.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $5.61.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: acrylic to their order.
# Customer Grace checked out and paid $3.68.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: oil to their order.
# Customer Aaron checked out and paid $9.78.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: oil to their order.
# Customer Ivy checked out and paid $2.03.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: acrylic to their order.
# Customer Lucas checked out and paid $3.68.
# The total sales for Local Store 1 today is $1398.1199999999983.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: red, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $5.52.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: watercolor to their order.
# Customer Bob checked out and paid $1.82.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $5.52.
# Customer David is shopping.
# Customer David added Color: blue, Medium: oil to their order.
# Customer David checked out and paid $7.11.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.52.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: marker to their order.
# Customer Billie checked out and paid $1.71.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: oil to their order.
# Customer Grace checked out and paid $7.06.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $5.51.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.5.
# Customer Lucas is shopping.
# Customer Lucas added Color: red, Medium: acrylic to their order.
# Customer Lucas checked out and paid $8.33.
# The total sales for Local Store 2 today is $1260.8899999999996.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: oil to their order.
# Customer Jennifer checked out and paid $6.07.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: oil to their order.
# Customer Bob checked out and paid $6.07.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $1.5.
# Customer David is shopping.
# Customer David added Color: red, Medium: watercolor to their order.
# Customer David checked out and paid $1.5.
# Customer Eve is shopping.
# Customer Eve added Color: green, Medium: acrylic to their order.
# Customer Eve checked out and paid $5.82.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: marker to their order.
# Customer Billie checked out and paid $8.94.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: marker to their order.
# Customer Grace checked out and paid $1.12.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $4.31.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $8.41.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: watercolor to their order.
# Customer Lucas checked out and paid $5.0.
# The total sales for Local Store 3 today is $1268.84.
# The total sales for Flying Colors today is $3927.8499999999976.
#       store_name  weekly_sales
# 0  Flying Colors       3927.85
# The total sales for Flying Colors today is $3927.8499999999976.
#       store_name  weekly_sales
# 0  Flying Colors       3927.85
# Running simulation for week 23
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: marker to their order.
# Customer Jennifer checked out and paid $5.61.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: acrylic to their order.
# Customer Bob checked out and paid $3.68.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: oil to their order.
# Customer Charlie checked out and paid $5.4.
# Customer David is shopping.
# Customer David added Color: orange, Medium: oil to their order.
# Customer David checked out and paid $2.03.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: oil to their order.
# Customer Eve checked out and paid $9.6.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $5.61.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: oil to their order.
# Customer Grace checked out and paid $9.78.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $9.6.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.77.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: oil to their order.
# Customer Lucas checked out and paid $2.03.
# The total sales for Local Store 1 today is $1457.229999999998.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: marker to their order.
# Customer Jennifer checked out and paid $5.12.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $1.26.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: acrylic to their order.
# Customer Charlie checked out and paid $8.33.
# Customer David is shopping.
# Customer David added Color: green, Medium: oil to their order.
# Customer David checked out and paid $8.25.
# Customer Eve is shopping.
# Customer Eve added Color: green, Medium: marker to their order.
# Customer Eve checked out and paid $6.74.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: acrylic to their order.
# Customer Billie checked out and paid $8.33.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: acrylic to their order.
# Customer Grace checked out and paid $8.33.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $6.74.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: marker to their order.
# Customer Ivy checked out and paid $5.12.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: watercolor to their order.
# Customer Lucas checked out and paid $8.74.
# The total sales for Local Store 2 today is $1327.8499999999992.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: oil to their order.
# Customer Jennifer checked out and paid $6.07.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: watercolor to their order.
# Customer Bob checked out and paid $7.47.
# Customer Charlie is shopping.
# Customer Charlie added Color: green, Medium: acrylic to their order.
# Customer Charlie checked out and paid $5.82.
# Customer David is shopping.
# Customer David added Color: green, Medium: oil to their order.
# Customer David checked out and paid $5.04.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: watercolor to their order.
# Customer Eve checked out and paid $8.22.
# Customer Billie is shopping.
# Customer Billie added Color: green, Medium: acrylic to their order.
# Customer Billie checked out and paid $4.83.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: oil to their order.
# Customer Grace checked out and paid $6.07.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: marker to their order.
# Customer Aaron checked out and paid $8.94.
# Customer Ivy is shopping.
# Customer Ivy added Color: red, Medium: watercolor to their order.
# Customer Ivy checked out and paid $6.71.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: watercolor to their order.
# Customer Lucas checked out and paid $9.12.
# The total sales for Local Store 3 today is $1337.1299999999997.
# The total sales for Flying Colors today is $4122.209999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4122.21
# The total sales for Flying Colors today is $4122.209999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4122.21
# Running simulation for week 24
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $3.68.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: oil to their order.
# Customer Bob checked out and paid $9.6.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: oil to their order.
# Customer Charlie checked out and paid $9.78.
# Customer David is shopping.
# Customer David added Color: blue, Medium: acrylic to their order.
# Customer David checked out and paid $9.64.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.77.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: acrylic to their order.
# Customer Billie checked out and paid $3.68.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: acrylic to their order.
# Customer Grace checked out and paid $3.68.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $5.61.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $1.42.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: acrylic to their order.
# Customer Lucas checked out and paid $3.68.
# The total sales for Local Store 1 today is $1513.7699999999982.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: red, Medium: marker to their order.
# Customer Jennifer checked out and paid $1.71.
# Customer Bob is shopping.
# Customer Bob added Color: red, Medium: marker to their order.
# Customer Bob checked out and paid $1.71.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: watercolor to their order.
# Customer Charlie checked out and paid $5.5.
# Customer David is shopping.
# Customer David added Color: orange, Medium: marker to their order.
# Customer David checked out and paid $1.26.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: oil to their order.
# Customer Eve checked out and paid $7.06.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: watercolor to their order.
# Customer Billie checked out and paid $1.82.
# Customer Grace is shopping.
# Customer Grace added Color: green, Medium: oil to their order.
# Customer Grace checked out and paid $8.25.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: watercolor to their order.
# Customer Aaron checked out and paid $1.82.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.5.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: marker to their order.
# Customer Lucas checked out and paid $5.12.
# The total sales for Local Store 2 today is $1367.599999999999.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: red, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $1.4.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: watercolor to their order.
# Customer Bob checked out and paid $7.47.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: marker to their order.
# Customer Charlie checked out and paid $4.29.
# Customer David is shopping.
# Customer David added Color: blue, Medium: acrylic to their order.
# Customer David checked out and paid $8.98.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: oil to their order.
# Customer Eve checked out and paid $6.07.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: acrylic to their order.
# Customer Billie checked out and paid $1.4.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: watercolor to their order.
# Customer Grace checked out and paid $7.47.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: marker to their order.
# Customer Aaron checked out and paid $8.94.
# Customer Ivy is shopping.
# Customer Ivy added Color: red, Medium: marker to their order.
# Customer Ivy checked out and paid $1.12.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: oil to their order.
# Customer Lucas checked out and paid $5.04.
# The total sales for Local Store 3 today is $1389.3099999999997.
# The total sales for Flying Colors today is $4270.679999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4270.68
# The total sales for Flying Colors today is $4270.679999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4270.68
# Running simulation for week 25
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: oil to their order.
# Customer Jennifer checked out and paid $5.4.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: acrylic to their order.
# Customer Bob checked out and paid $9.64.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: watercolor to their order.
# Customer Charlie checked out and paid $5.77.
# Customer David is shopping.
# Customer David added Color: blue, Medium: oil to their order.
# Customer David checked out and paid $5.4.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: oil to their order.
# Customer Eve checked out and paid $2.03.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: oil to their order.
# Customer Billie checked out and paid $9.6.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: oil to their order.
# Customer Grace checked out and paid $2.03.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $9.6.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $8.67.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: acrylic to their order.
# Customer Lucas checked out and paid $9.64.
# The total sales for Local Store 1 today is $1581.5499999999984.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: green, Medium: oil to their order.
# Customer Jennifer checked out and paid $8.25.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: watercolor to their order.
# Customer Bob checked out and paid $1.82.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: acrylic to their order.
# Customer Charlie checked out and paid $8.33.
# Customer David is shopping.
# Customer David added Color: red, Medium: acrylic to their order.
# Customer David checked out and paid $8.33.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: oil to their order.
# Customer Eve checked out and paid $7.11.
# Customer Billie is shopping.
# Customer Billie added Color: green, Medium: marker to their order.
# Customer Billie checked out and paid $6.74.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: watercolor to their order.
# Customer Grace checked out and paid $5.52.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: marker to their order.
# Customer Aaron checked out and paid $1.71.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: oil to their order.
# Customer Ivy checked out and paid $5.51.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: watercolor to their order.
# Customer Lucas checked out and paid $5.5.
# The total sales for Local Store 2 today is $1426.4199999999987.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: red, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $1.5.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $8.41.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $6.71.
# Customer David is shopping.
# Customer David added Color: green, Medium: acrylic to their order.
# Customer David checked out and paid $4.83.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $7.25.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: watercolor to their order.
# Customer Billie checked out and paid $8.22.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: watercolor to their order.
# Customer Grace checked out and paid $7.47.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: marker to their order.
# Customer Aaron checked out and paid $8.94.
# Customer Ivy is shopping.
# Customer Ivy added Color: red, Medium: watercolor to their order.
# Customer Ivy checked out and paid $6.02.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: marker to their order.
# Customer Lucas checked out and paid $8.94.
# The total sales for Local Store 3 today is $1457.6.
# The total sales for Flying Colors today is $4465.569999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4465.57
# The total sales for Flying Colors today is $4465.569999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4465.57
# Running simulation for week 26
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $3.68.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: oil to their order.
# Customer Bob checked out and paid $9.6.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: oil to their order.
# Customer Charlie checked out and paid $2.03.
# Customer David is shopping.
# Customer David added Color: orange, Medium: oil to their order.
# Customer David checked out and paid $2.03.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: oil to their order.
# Customer Eve checked out and paid $9.78.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: acrylic to their order.
# Customer Billie checked out and paid $3.68.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $5.61.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: oil to their order.
# Customer Aaron checked out and paid $2.03.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: oil to their order.
# Customer Ivy checked out and paid $2.03.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: acrylic to their order.
# Customer Lucas checked out and paid $3.68.
# The total sales for Local Store 1 today is $1625.6999999999982.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: green, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $8.74.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: marker to their order.
# Customer Bob checked out and paid $5.12.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $8.65.
# Customer David is shopping.
# Customer David added Color: green, Medium: marker to their order.
# Customer David checked out and paid $6.74.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: marker to their order.
# Customer Eve checked out and paid $1.71.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $1.26.
# Customer Grace is shopping.
# Customer Grace added Color: blue, Medium: watercolor to their order.
# Customer Grace checked out and paid $1.82.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $6.74.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $1.82.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: oil to their order.
# Customer Lucas checked out and paid $7.06.
# The total sales for Local Store 2 today is $1476.0799999999986.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: oil to their order.
# Customer Jennifer checked out and paid $6.07.
# Customer Bob is shopping.
# Customer Bob added Color: red, Medium: marker to their order.
# Customer Bob checked out and paid $1.12.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $8.41.
# Customer David is shopping.
# Customer David added Color: blue, Medium: marker to their order.
# Customer David checked out and paid $4.29.
# Customer Eve is shopping.
# Customer Eve added Color: green, Medium: acrylic to their order.
# Customer Eve checked out and paid $5.82.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: watercolor to their order.
# Customer Billie checked out and paid $7.25.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: watercolor to their order.
# Customer Grace checked out and paid $7.47.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: watercolor to their order.
# Customer Aaron checked out and paid $5.0.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $9.12.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: watercolor to their order.
# Customer Lucas checked out and paid $5.0.
# The total sales for Local Store 3 today is $1517.1499999999996.
# The total sales for Flying Colors today is $4618.929999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4618.93
# The total sales for Flying Colors today is $4618.929999999997.
#       store_name  weekly_sales
# 0  Flying Colors       4618.93
# Running simulation for week 27
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $3.68.
# Customer Bob is shopping.
# Customer Bob added Color: red, Medium: oil to their order.
# Customer Bob checked out and paid $9.78.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: oil to their order.
# Customer Charlie checked out and paid $5.4.
# Customer David is shopping.
# Customer David added Color: blue, Medium: oil to their order.
# Customer David checked out and paid $5.4.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.77.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: acrylic to their order.
# Customer Billie checked out and paid $3.68.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $8.67.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: oil to their order.
# Customer Aaron checked out and paid $9.78.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: oil to their order.
# Customer Ivy checked out and paid $2.03.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: oil to their order.
# Customer Lucas checked out and paid $5.4.
# The total sales for Local Store 1 today is $1685.2899999999986.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: green, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $8.74.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: watercolor to their order.
# Customer Bob checked out and paid $1.82.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: marker to their order.
# Customer Charlie checked out and paid $1.71.
# Customer David is shopping.
# Customer David added Color: red, Medium: acrylic to their order.
# Customer David checked out and paid $8.33.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: marker to their order.
# Customer Eve checked out and paid $1.71.
# Customer Billie is shopping.
# Customer Billie added Color: green, Medium: watercolor to their order.
# Customer Billie checked out and paid $8.74.
# Customer Grace is shopping.
# Customer Grace added Color: green, Medium: watercolor to their order.
# Customer Grace checked out and paid $8.74.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $1.26.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.5.
# Customer Lucas is shopping.
# Customer Lucas added Color: red, Medium: marker to their order.
# Customer Lucas checked out and paid $1.71.
# The total sales for Local Store 2 today is $1524.3399999999986.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $7.47.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $8.41.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $4.31.
# Customer David is shopping.
# Customer David added Color: orange, Medium: watercolor to their order.
# Customer David checked out and paid $7.25.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: acrylic to their order.
# Customer Eve checked out and paid $8.98.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: marker to their order.
# Customer Billie checked out and paid $1.12.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $4.31.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: watercolor to their order.
# Customer Aaron checked out and paid $1.5.
# Customer Ivy is shopping.
# Customer Ivy added Color: red, Medium: marker to their order.
# ...
# Customer Jennifer added Color: orange, Medium: marker to their order.
# Customer Jennifer checked out and paid $8.65.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: watercolor to their order.
# Customer Bob checked out and paid $5.5.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $6.74.
# Customer David is shopping.
# Customer David added Color: blue, Medium: watercolor to their order.
# Customer David checked out and paid $5.5.
# Customer Eve is shopping.
# Customer Eve added Color: green, Medium: watercolor to their order.
# Customer Eve checked out and paid $8.74.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $6.74.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: watercolor to their order.
# Customer Grace checked out and paid $5.52.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $7.11.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: marker to their order.
# Customer Ivy checked out and paid $8.65.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: marker to their order.
# Customer Lucas checked out and paid $1.26.
# The total sales for Local Store 2 today is $2892.129999999999.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $7.25.
# Customer Bob is shopping.
# Customer Bob added Color: green, Medium: oil to their order.
# Customer Bob checked out and paid $5.04.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $1.5.
# Customer David is shopping.
# Customer David added Color: orange, Medium: marker to their order.
# Customer David checked out and paid $8.41.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: marker to their order.
# Customer Eve checked out and paid $4.31.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: watercolor to their order.
# Customer Billie checked out and paid $7.47.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: watercolor to their order.
# Customer Grace checked out and paid $7.47.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: watercolor to their order.
# Customer Aaron checked out and paid $6.02.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: oil to their order.
# Customer Ivy checked out and paid $6.07.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: acrylic to their order.
# Customer Lucas checked out and paid $4.83.
# The total sales for Local Store 3 today is $2906.3399999999947.
# The total sales for Flying Colors today is $8848.299999999996.
#       store_name  weekly_sales
# 0  Flying Colors        8848.3
# The total sales for Flying Colors today is $8848.299999999996.
#       store_name  weekly_sales
# 0  Flying Colors        8848.3
# Running simulation for week 51
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $5.77.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $8.67.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: acrylic to their order.
# Customer Charlie checked out and paid $9.64.
# Customer David is shopping.
# Customer David added Color: orange, Medium: marker to their order.
# Customer David checked out and paid $5.61.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: marker to their order.
# Customer Eve checked out and paid $5.61.
# Customer Billie is shopping.
# Customer Billie added Color: orange, Medium: marker to their order.
# Customer Billie checked out and paid $5.61.
# Customer Grace is shopping.
# Customer Grace added Color: blue, Medium: oil to their order.
# Customer Grace checked out and paid $5.4.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: marker to their order.
# Customer Aaron checked out and paid $5.61.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.77.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: oil to their order.
# Customer Lucas checked out and paid $9.6.
# The total sales for Local Store 1 today is $3117.120000000003.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: marker to their order.
# Customer Jennifer checked out and paid $8.65.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: oil to their order.
# Customer Bob checked out and paid $7.06.
# Customer Charlie is shopping.
# Customer Charlie added Color: blue, Medium: marker to their order.
# Customer Charlie checked out and paid $5.12.
# Customer David is shopping.
# Customer David added Color: blue, Medium: watercolor to their order.
# Customer David checked out and paid $1.82.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.52.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: oil to their order.
# Customer Billie checked out and paid $7.11.
# Customer Grace is shopping.
# Customer Grace added Color: red, Medium: watercolor to their order.
# Customer Grace checked out and paid $5.52.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: watercolor to their order.
# Customer Aaron checked out and paid $1.82.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: oil to their order.
# Customer Ivy checked out and paid $7.11.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: watercolor to their order.
# Customer Lucas checked out and paid $1.82.
# The total sales for Local Store 2 today is $2943.68.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: blue, Medium: marker to their order.
# Customer Jennifer checked out and paid $8.94.
# Customer Bob is shopping.
# Customer Bob added Color: red, Medium: watercolor to their order.
# Customer Bob checked out and paid $6.71.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: watercolor to their order.
# Customer Charlie checked out and paid $7.47.
# Customer David is shopping.
# Customer David added Color: blue, Medium: marker to their order.
# Customer David checked out and paid $4.29.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: oil to their order.
# Customer Eve checked out and paid $6.07.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: marker to their order.
# Customer Billie checked out and paid $8.94.
# Customer Grace is shopping.
# Customer Grace added Color: green, Medium: acrylic to their order.
# Customer Grace checked out and paid $5.82.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: watercolor to their order.
# Customer Aaron checked out and paid $6.02.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: watercolor to their order.
# Customer Ivy checked out and paid $5.0.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: acrylic to their order.
# Customer Lucas checked out and paid $5.82.
# The total sales for Local Store 3 today is $2971.419999999995.
# The total sales for Flying Colors today is $9032.219999999998.
#       store_name  weekly_sales
# 0  Flying Colors       9032.22
# The total sales for Flying Colors today is $9032.219999999998.
#       store_name  weekly_sales
# 0  Flying Colors       9032.22
# Running simulation for week 52
# We'd like to welcome you to Flying Colors!
# We have 3 stores in our corporation.
# Welcome to Local Store 1!
# Color: orange, Medium: marker
# Color: red, Medium: oil
# Color: orange, Medium: acrylic
# Color: orange, Medium: watercolor
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: blue, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: blue, Medium: oil
# Color: blue, Medium: oil
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: acrylic to their order.
# Customer Jennifer checked out and paid $3.68.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: acrylic to their order.
# Customer Bob checked out and paid $9.64.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: oil to their order.
# Customer Charlie checked out and paid $2.03.
# Customer David is shopping.
# Customer David added Color: blue, Medium: acrylic to their order.
# Customer David checked out and paid $9.64.
# Customer Eve is shopping.
# Customer Eve added Color: blue, Medium: oil to their order.
# Customer Eve checked out and paid $5.4.
# Customer Billie is shopping.
# Customer Billie added Color: red, Medium: oil to their order.
# Customer Billie checked out and paid $9.78.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: marker to their order.
# Customer Grace checked out and paid $8.67.
# Customer Aaron is shopping.
# Customer Aaron added Color: orange, Medium: oil to their order.
# Customer Aaron checked out and paid $2.03.
# Customer Ivy is shopping.
# Customer Ivy added Color: blue, Medium: acrylic to their order.
# Customer Ivy checked out and paid $9.64.
# Customer Lucas is shopping.
# Customer Lucas added Color: blue, Medium: oil to their order.
# Customer Lucas checked out and paid $9.6.
# The total sales for Local Store 1 today is $3187.230000000003.
# Welcome to Local Store 2!
# Color: orange, Medium: oil
# Color: orange, Medium: marker
# Color: green, Medium: oil
# Color: orange, Medium: marker
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: blue, Medium: watercolor
# Color: red, Medium: acrylic
# Color: blue, Medium: oil
# Color: red, Medium: marker
# Color: blue, Medium: oil
# Color: blue, Medium: watercolor
# Color: red, Medium: watercolor
# Color: green, Medium: marker
# Color: green, Medium: watercolor
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: green, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $8.74.
# Customer Bob is shopping.
# Customer Bob added Color: blue, Medium: marker to their order.
# Customer Bob checked out and paid $5.12.
# Customer Charlie is shopping.
# Customer Charlie added Color: red, Medium: watercolor to their order.
# Customer Charlie checked out and paid $5.52.
# Customer David is shopping.
# Customer David added Color: blue, Medium: watercolor to their order.
# Customer David checked out and paid $5.5.
# Customer Eve is shopping.
# Customer Eve added Color: red, Medium: marker to their order.
# Customer Eve checked out and paid $1.71.
# Customer Billie is shopping.
# Customer Billie added Color: green, Medium: oil to their order.
# Customer Billie checked out and paid $8.25.
# Customer Grace is shopping.
# Customer Grace added Color: blue, Medium: marker to their order.
# Customer Grace checked out and paid $5.12.
# Customer Aaron is shopping.
# Customer Aaron added Color: blue, Medium: oil to their order.
# Customer Aaron checked out and paid $5.51.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: oil to their order.
# Customer Ivy checked out and paid $7.06.
# Customer Lucas is shopping.
# Customer Lucas added Color: green, Medium: oil to their order.
# Customer Lucas checked out and paid $8.25.
# The total sales for Local Store 2 today is $3004.4599999999996.
# Welcome to Local Store 3!
# Color: red, Medium: watercolor
# Color: orange, Medium: watercolor
# Color: blue, Medium: acrylic
# Color: red, Medium: marker
# Color: orange, Medium: watercolor
# Color: green, Medium: oil
# Color: orange, Medium: watercolor
# Color: red, Medium: acrylic
# Color: red, Medium: watercolor
# Color: green, Medium: acrylic
# Color: blue, Medium: watercolor
# Color: blue, Medium: marker
# Color: orange, Medium: marker
# Color: green, Medium: acrylic
# Color: orange, Medium: marker
# Color: orange, Medium: oil
# Color: red, Medium: watercolor
# Color: red, Medium: watercolor
# Color: blue, Medium: marker
# We have 10 customers today.
# Customer Jennifer is shopping.
# Customer Jennifer added Color: orange, Medium: watercolor to their order.
# Customer Jennifer checked out and paid $7.25.
# Customer Bob is shopping.
# Customer Bob added Color: orange, Medium: marker to their order.
# Customer Bob checked out and paid $4.31.
# Customer Charlie is shopping.
# Customer Charlie added Color: orange, Medium: marker to their order.
# Customer Charlie checked out and paid $8.41.
# Customer David is shopping.
# Customer David added Color: orange, Medium: marker to their order.
# Customer David checked out and paid $8.41.
# Customer Eve is shopping.
# Customer Eve added Color: orange, Medium: watercolor to their order.
# Customer Eve checked out and paid $5.0.
# Customer Billie is shopping.
# Customer Billie added Color: blue, Medium: watercolor to their order.
# Customer Billie checked out and paid $9.12.
# Customer Grace is shopping.
# Customer Grace added Color: orange, Medium: oil to their order.
# Customer Grace checked out and paid $6.07.
# Customer Aaron is shopping.
# Customer Aaron added Color: red, Medium: acrylic to their order.
# Customer Aaron checked out and paid $1.4.
# Customer Ivy is shopping.
# Customer Ivy added Color: orange, Medium: watercolor to their order.
# Customer Ivy checked out and paid $7.47.
# Customer Lucas is shopping.
# Customer Lucas added Color: orange, Medium: oil to their order.
# Customer Lucas checked out and paid $6.07.
# The total sales for Local Store 3 today is $3034.929999999995.
# The total sales for Flying Colors today is $9226.619999999997.
#       store_name  weekly_sales
# 0  Flying Colors       9226.62
# The total sales for Flying Colors today is $9226.619999999997.
#       store_name  weekly_sales
# 0  Flying Colors       9226.62
# alt.VConcatChart(...)

# %%
#in case you run into trouble, and you need to clear out your folder, here:
import os

# Get the current working directory
cwd = os.getcwd()

# List all files in the directory
files = os.listdir(cwd)

# Filter for CSV files
csv_files = [f for f in files if f.endswith('.csv')]

# Delete each CSV file
for f in csv_files:
    os.remove(os.path.join(cwd, f))
